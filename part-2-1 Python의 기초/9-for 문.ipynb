# %%
# for 문으로 반복 처리를 할 수 있다
"""
for 변수 in 리스트:
    처리
"""

"""
for a in reange(정수):
    처리
"""

# %%
# for 문과 리스트를 사용한 루프
for a in [4, 7, 10]:
    print(a + 1)
# Out:
# 5
# 8
# 11

# %%
# range()를 사용한 루프
for a in range(5):
    print(a)
# Out:
# 5
# 5
# 5
# 5
# 5
